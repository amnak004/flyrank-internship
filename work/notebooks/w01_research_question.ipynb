# %% [markdown]
# <a href="https://colab.research.google.com/github/amnak004/flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/amnak004/flyrank-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# ## My Lane
#
# I chose the Content Refresh Prioritization lane because many website pages lose traffic over time and it is difficult to manually decide which pages should be updated first. This project aims to identify pages that are most likely to need a content refresh so that SEO and content teams can focus on the highest priority pages. Machine learning can help rank these pages using available data instead of relying only on manual judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## The Question
#
# Decision:
# Which website pages should be refreshed first?
#
# Action:
# The SEO or content team will update the highest priority pages.
#
# Cost of a Wrong Recommendation:
# If the wrong pages are selected, valuable time will be spent updating pages that do not need attention while important declining pages may continue losing traffic.
#
# Why Machine Learning?
# Large websites may contain thousands of pages. Machine learning can analyze many signals together and help prioritize pages more efficiently than manual review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# ## Quick Look at the Data
#
# The starter dataset contains thousands of webpage records with information such as impressions, click-through rate (CTR), search volume, content age, and trend direction. I explored the data to understand whether it contains useful signals for prioritizing content updates.

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 3))
print("Median content age:", round(df["content_age_days"].median(), 0))
print("\nTrend Direction Counts:")
print(df["trend_direction"].value_counts())
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Median content age: 236.0
#
# Trend Direction Counts:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# ## Careful Words
#
# This project provides decision support based on observed patterns in the available data. It does not prove why a page gains or loses traffic, and it does not predict Google's algorithm. The results should be used to help prioritize decisions rather than replace human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
